# %%
import requests
import cv2
import warnings
import urllib.request, json
import re
import http.client, urllib.request, urllib.parse, urllib.error, base64
import csv

import scholarly as slr
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

from PIL import Image
from io import BytesIO
from math import ceil

# warnings.filterwarnings('ignore')

# %matplotlib inline

ROWS = 1000

# %%
class FakeInfo:
    def __init__(self, name):
        self.name = name
        self.id = hash(name)
        self.url_picture = '/citations/images/avatar_scholar_128.jpg'

# %%
class Network:
    def __init__(self):
        self.id_info = {}
        self.name_id = {}
    
    def split_full_name(self, author_name):
        full_name = author_name.replace('.', '').split(' ')
        names, surname = full_name[:-1], full_name[-1]
        if len(names) == 1 and names[0].isupper():
            names = [ch for ch in names[0]]
        return names, surname
    
    def possible_names(self, names, surname):
        surnames = surname.split('-')
        result = []
        for surname in surnames:
            surname = surname.title()
            for name in names:
                result += [name+' '+surname, name[0]+' '+surname, name[0]+'. '+surname]
        return result
    
    def compare_name(self, name1, name2):
        if len(name1) > 1 and len(name2) > 1:
            return name1 in name2 or name2 in name1
        return name1[0] == name2[0]
    
    def compare_names(self, fullname1, fullname2):
        names1, surname1 = self.split_full_name(fullname1)
        names2, surname2 = self.split_full_name(fullname2)
        
        if '-' in surname1 or '-' in surname2:
            res = self.compare_names(surname1.replace('-', ' ') + " abc", surname2.replace('-', ' ') + " abc")
        else:
            res = self.compare_name(surname1, surname2)

        if res:
            ptr1, ptr2 = 0, 0
            
            while ptr1 < len(names1) and ptr2 < len(names2):
                if self.compare_name(names1[ptr1], names2[ptr2]):
                    ptr1 += 1
                    ptr2 += 1
                else:
                    if len(names1) - ptr1 == len(names2) - ptr2:
                        return False
                    if len(names1) - ptr1 > len(names2) - ptr2:
                        ptr1 += 1
                    else:
                        ptr2 += 1
            return True
            
        return False
    
    def get_info(self, author_name):
        names, surname = self.split_full_name(author_name)
        
        for name in self.possible_names(names, surname):
            if name in self.name_id:
                print('\t {} is already in the database.'.format(author_name))
                if author_name not in self.name_id:
                    for other_name in self.possible_names(names, surname):
                        self.name_id[other_name] = self.name_id[name]
                return self.id_info[self.name_id[name]]
        
        author_info = FakeInfo(author_name)
        
        print('\t Adding {} in database.'.format(author_name))

        self.id_info[author_info.id] = author_info

        for name in self.possible_names(names, surname):
            self.name_id[name] = author_info.id

        if author_name != author_info.name:
            for name in self.possible_names(*self.split_full_name(author_info.name)):
                self.name_id[name] = author_info.id
            
        return author_info
        
    def add_author(self, G, author_name):
        print('Adding {}:'.format(author_name))
        
        author_info = self.get_info(author_name)
        
        if author_info.id in G.nodes():
            print('\t Author id is already in the network.')            
            return
        
        print('\t Adding {} to network.'.format(author_name))
        G.add_node(author_info.id)
                
    def add_coauthors(self, G, author_name):
        print("Adding {}'s co-authors:".format(author_name))
        author_info = self.id_info[self.name_id[author_name]]
        author_id = author_info.id
        
        coauthors = set()

        # Crossref
        print("\t Adding co-authors from Crossref")
        
        names, surname = self.split_full_name(author_name)
        with urllib.request.urlopen('https://api.crossref.org/works?query.author={}&rows=0'.format(surname)) as url:
            data = json.loads(url.read().decode())
        
        for i in range(ceil(data['message']['total-results'] / ROWS)):
            try:
                with urllib.request.urlopen(
                    'https://api.crossref.org/works?query.author={s}&rows={r}&offset={of}'.format(s=surname, r=ROWS,
                                                                                                 of=i*ROWS)) as url:
                    data = json.loads(url.read().decode())

            except:
                continue
                    
            for pub in data['message']['items']:
                for author in pub['author']:
                    try:
                        if surname in author['family']:
                            for name in names:
                                if len(name) > 1:
                                    if name in author['family'] or name in author['given']:
                                        for a in pub['author']:
                                            coauthors.add(a['given'] + ' ' + a['family'])
                    except:
                        continue
        
        # Microsoft Academic
        print("\t Adding co-authors from Microsoft Academic Knowledge")
        
        headers = {'Ocp-Apim-Subscription-Key': 'e2a75d980b2e4752bbe5e7f87fd72eea'}
        params = urllib.parse.urlencode({
            'expr': "Composite(AA.AuN='{}')".format(author_name.lower()),
            'attributes': 'AA.AuN'
        })

        try:
            conn = http.client.HTTPSConnection('westus.api.cognitive.microsoft.com')
            conn.request("GET", "/academic/v1.0/evaluate?%s" % params, "{body}", headers)
            response = conn.getresponse()
            data = response.read()
            conn.close()
        except Exception as e:
            print("[Errno {0}] {1}".format(e.errno, e.strerror))
            
        for match in re.finditer(b"\"AuN\"\:\"([\w ]+)\"", data):
            coauthors.add(match.group(1).decode().title())

        print()
        
        surnames = {}
        
        for name in coauthors:
            surname = name.replace('.', '').split(' ')[-1]
            if surname not in surnames or (len(surnames[surname]) < len(name) and 
                                           self.compare_names(name, surnames[surname])):
                surnames[surname] = name
        
        for surname in surnames:
            coauthor_info = self.get_info(surnames[surname])
            
            if coauthor_info.id != author_id:
                self.add_author(G, coauthor_info.name)
                print('\t Adding connection between {a} and {c}.\n'.format(a=author_name, c=coauthor_info.name))
                G.add_edge(author_id, coauthor_info.id)

# %%
G = nx.Graph()

# %%
gn = Network()

# %%
gn.add_author(G, 'Arseny Alexeev')
# Out:
# Adding Arseny Alexeev:
# 	 Adding Arseny Alexeev in database.
# 	 Adding Arseny Alexeev to network.

# %%
gn.add_coauthors(G, 'M Portnoi')
# Out:
# Adding M Portnoi's co-authors:
# 	 Adding co-authors from Crossref
# 	 Adding co-authors from Microsoft Academic Knowledge
#
# 	 Adding Valerie Malan in database.
# Adding Valerie Malan:
# 	 Valerie Malan is already in the database.
# 	 Adding Valerie Malan to network.
# 	 Adding connection between M Portnoi and Valerie Malan.
#
# 	 Adding Gerard Pals in database.
# Adding Gerard Pals:
# 	 Gerard Pals is already in the database.
# 	 Adding Gerard Pals to network.
# 	 Adding connection between M Portnoi and Gerard Pals.
#
# 	 Adding Vladimir Mordachev in database.
# Adding Vladimir Mordachev:
# 	 Vladimir Mordachev is already in the database.
# 	 Adding Vladimir Mordachev to network.
# 	 Adding connection between M Portnoi and Vladimir Mordachev.
#
# 	 Adding Christel Thauvinrobinet in database.
# Adding Christel Thauvinrobinet:
# 	 Christel Thauvinrobinet is already in the database.
# 	 Adding Christel Thauvinrobinet to network.
# 	 Adding connection between M Portnoi and Christel Thauvinrobinet.
#
# 	 Marie France Portnoi is already in the database.
# 	 Adding Christopher G Mathew in database.
# Adding Christopher G Mathew:
# 	 Christopher G Mathew is already in the database.
# 	 Adding Christopher G Mathew to network.
# 	 Adding connection between M Portnoi and Christopher G Mathew.
#
# 	 Adding Vered Chalifacaspi in database.
# Adding Vered Chalifacaspi:
# 	 Vered Chalifacaspi is already in the database.
# 	 Adding Vered Chalifacaspi to network.
# 	 Adding connection between M Portnoi and Vered Chalifacaspi.
#
# 	 Adding Rene Frydman in database.
# Adding Rene Frydman:
# 	 Rene Frydman is already in the database.
# 	 Adding Rene Frydman to network.
# 	 Adding connection between M Portnoi and Rene Frydman.
#
# 	 Adding Yaffa Mizrachinebenzahl in database.
# Adding Yaffa Mizrachinebenzahl:
# 	 Yaffa Mizrachinebenzahl is already in the database.
# 	 Adding Yaffa Mizrachinebenzahl to network.
# 	 Adding connection between M Portnoi and Yaffa Mizrachinebenzahl.
#
# 	 Adding Martine Le Merrer in database.
# Adding Martine Le Merrer:
# 	 Martine Le Merrer is already in the database.
# 	 Adding Martine Le Merrer to network.
# 	 Adding connection between M Portnoi and Martine Le Merrer.
#
# 	 Adding F Lebas in database.
# Adding F Lebas:
# 	 F Lebas is already in the database.
# 	 Adding F Lebas to network.
# 	 Adding connection between M Portnoi and F Lebas.
#
# 	 Adding Eduard Ling in database.
# Adding Eduard Ling:
# 	 Eduard Ling is already in the database.
# 	 Adding Eduard Ling to network.
# 	 Adding connection between M Portnoi and Eduard Ling.
#
# 	 Adding G Tachdjian in database.
# Adding G Tachdjian:
# 	 G Tachdjian is already in the database.
# 	 Adding G Tachdjian to network.
# 	 Adding connection between M Portnoi and G Tachdjian.
#
# 	 Adding S Ducrocq in database.
# Adding S Ducrocq:
# 	 S Ducrocq is already in the database.
# 	 Adding S Ducrocq to network.
# 	 Adding connection between M Portnoi and S Ducrocq.
#
# 	 Adding Azzedine Aboura in database.
# Adding Azzedine Aboura:
# 	 Azzedine Aboura is already in the database.
# 	 Adding Azzedine Aboura to network.
# 	 Adding connection between M Portnoi and Azzedine Aboura.
#
# 	 Adding N Roncichaix in database.
# Adding N Roncichaix:
# 	 N Roncichaix is already in the database.
# 	 Adding N Roncichaix to network.
# 	 Adding connection between M Portnoi and N Roncichaix.
#
# 	 G Feldman is already in the database.
# Adding G J Feldman:
# 	 G J Feldman is already in the database.
# 	 Author id is already in the network.
# 	 Adding connection between M Portnoi and G J Feldman.
#
# 	 Adding Dominique Stoppalyonnet in database.
# Adding Dominique Stoppalyonnet:
# 	 Dominique Stoppalyonnet is already in the database.
# 	 Adding Dominique Stoppalyonnet to network.
# 	 Adding connection between M Portnoi and Dominique Stoppalyonnet.
#
# 	 Adding F Gold in database.
# Adding F Gold:
# 	 F Gold is already in the database.
# 	 Adding F Gold to network.
# 	 Adding connection between M Portnoi and F Gold.
#
# 	 Nicole Robinson is already in the database.
# Adding Nicole Robinson:
# 	 Nicole Robinson is already in the database.
# 	 Author id is already in the network.
# 	 Adding connection between M Portnoi and Nicole Robinson.
#
# 	 Adding Valerie Biranmucignat in database.
# Adding Valerie Biranmucignat:
# 	 Valerie Biranmucignat is already in the database.
# 	 Adding Valerie Biranmucignat to network.
# 	 Adding connection between M Portnoi and Valerie Biranmucignat.
#
# 	 Adding G Miano in database.
# Adding G Miano:
# 	 G Miano is already in the database.
# 	 Adding G Miano to network.
# 	 Adding connection between M Portnoi and G Miano.
#
# 	 J Kono is already in the database.
# Adding J Kono:
# 	 J Kono is already in the database.
# 	 Author id is already in the network.
# 	 Adding connection between M Portnoi and J Kono.
#
# 	 Adding Eugene Sinkevich in database.
# Adding Eugene Sinkevich:
# 	 Eugene Sinkevich is already in the database.
# 	 Adding Eugene Sinkevich to network.
# 	 Adding connection between M Portnoi and Eugene Sinkevich.
#
# 	 Adding Jerry M Wells in database.
# Adding Jerry M Wells:
# 	 Jerry M Wells is already in the database.
# 	 Adding Jerry M Wells to network.
# 	 Adding connection between M Portnoi and Jerry M Wells.
#
# 	 Adding Nicolas Gruchy in database.
# Adding Nicolas Gruchy:
# 	 Nicolas Gruchy is already in the database.
# 	 Adding Nicolas Gruchy to network.
# 	 Adding connection between M Portnoi and Nicolas Gruchy.
#
# 	 Adding Ron Dagan in database.
# Adding Ron Dagan:
# 	 Ron Dagan is already in the database.
# 	 Adding Ron Dagan to network.
# 	 Adding connection between M Portnoi and Ron Dagan.
#
# 	 M Rosenau Da Costa is already in the database.
# Adding G Da Costa:
# 	 G Da Costa is already in the database.
# 	 Author id is already in the network.
# 	 Adding connection between M Portnoi and G Da Costa.
#
# 	 Adding Lina Finkel in database.
# Adding Lina Finkel:
# 	 Lina Finkel is already in the database.
# 	 Adding Lina Finkel to network.
# 	 Adding connection between M Portnoi and Lina Finkel.
#
# 	 Adding Alain Verloes in database.
# Adding Alain Verloes:
# 	 Alain Verloes is already in the database.
# 	 Adding Alain Verloes to network.
# 	 Adding connection between M Portnoi and Alain Verloes.
#
# 	 Adding Bart C J M Fauser in database.
# Adding Bart C J M Fauser:
# 	 Bart C J M Fauser is already in the database.
# 	 Adding Bart C J M Fauser to network.
# 	 Adding connection between M Portnoi and Bart C J M Fauser.
#
# 	 Adding Gilles Roger in database.
# Adding Gilles Roger:
# 	 Gilles Roger is already in the database.
# 	 Adding Gilles Roger to network.
# 	 Adding connection between M Portnoi and Gilles Roger.
#
# 	 Adding Gregory Ya Slepyan in database.
# Adding Gregory Ya Slepyan:
# 	 Gregory Ya Slepyan is already in the database.
# 	 Adding Gregory Ya Slepyan to network.
# 	 Adding connection between M Portnoi and Gregory Ya Slepyan.
#
# 	 Adding Laurence Faivre in database.
# Adding Laurence Faivre:
# 	 Laurence Faivre is already in the database.
# 	 Adding Laurence Faivre to network.
# 	 Adding connection between M Portnoi and Laurence Faivre.
#
# 	 Adding Bruno Donadille in database.
# Adding Bruno Donadille:
# 	 Bruno Donadille is already in the database.
# 	 Adding Bruno Donadille to network.
# 	 Adding connection between M Portnoi and Bruno Donadille.
#
# 	 Adding N Bourcigaux in database.
# Adding N Bourcigaux:
# 	 N Bourcigaux is already in the database.
# 	 Adding N Bourcigaux to network.
# 	 Adding connection between M Portnoi and N Bourcigaux.
#
# 	 Adding S A Maksimenko in database.
# Adding S A Maksimenko:
# 	 S A Maksimenko is already in the database.
# 	 Adding S A Maksimenko to network.
# 	 Adding connection between M Portnoi and S A Maksimenko.
#
# 	 Richard R Hartmann is already in the database.
# Adding Richard R Hartmann:
# 	 Richard R Hartmann is already in the database.
# 	 Author id is already in the network.
# 	 Adding connection between M Portnoi and Richard R Hartmann.
#
# 	 Adding O V Kibis in database.
# Adding O V Kibis:
# 	 O V Kibis is already in the database.
# 	 Adding O V Kibis to network.
# 	 Adding connection between M Portnoi and O V Kibis.
#
# 	 Adding Sandrine Marlin in database.
# Adding Sandrine Marlin:
# 	 Sandrine Marlin is already in the database.
# 	 Adding Sandrine Marlin to network.
# 	 Adding connection between M Portnoi and Sandrine Marlin.
#
# 	 Adding Antonio Maffucci in database.
# Adding Antonio Maffucci:
# 	 Antonio Maffucci is already in the database.
# 	 Adding Antonio Maffucci to network.
# 	 Adding connection between M Portnoi and Antonio Maffucci.
#
# 	 Adding Amir Boag in database.
# Adding Amir Boag:
# 	 Amir Boag is already in the database.
# 	 Adding Amir Boag to network.
# 	 Adding connection between M Portnoi and Amir Boag.
#
# 	 Adding Sophie Christinmaitre in database.
# Adding Sophie Christinmaitre:
# 	 Sophie Christinmaitre is already in the database.
# 	 Adding Sophie Christinmaitre to network.
# 	 Adding connection between M Portnoi and Sophie Christinmaitre.
#
# 	 Adding Karin Overweg in database.
# Adding Karin Overweg:
# 	 Karin Overweg is already in the database.
# 	 Adding Karin Overweg to network.
# 	 Adding connection between M Portnoi and Karin Overweg.
#
# 	 Adding Philippe Bouchard in database.
# Adding Philippe Bouchard:
# 	 Philippe Bouchard is already in the database.
# 	 Adding Philippe Bouchard to network.
# 	 Adding connection between M Portnoi and Philippe Bouchard.
#
# 	 Adding Claire Dupas in database.
# Adding Claire Dupas:
# 	 Claire Dupas is already in the database.
# 	 Adding Claire Dupas to network.
# 	 Adding connection between M Portnoi and Claire Dupas.
#
# 	 Adding Frederic Huet in database.
# Adding Frederic Huet:
# 	 Frederic Huet is already in the database.
# 	 Adding Frederic Huet to network.
# 	 Adding connection between M Portnoi and Frederic Huet.
#
# 	 Adding P Kuzhir in database.
# Adding P Kuzhir:
# 	 P Kuzhir is already in the database.
# 	 Adding P Kuzhir to network.
# 	 Adding connection between M Portnoi and P Kuzhir.
#
# 	 Adding Azarnouche Ardalan in database.
# Adding Azarnouche Ardalan:
# 	 Azarnouche Ardalan is already in the database.
# 	 Adding Azarnouche Ardalan to network.
# 	 Adding connection between M Portnoi and Azarnouche Ardalan.
#
# 	 Adding D Dewailly in database.
# Adding D Dewailly:
# 	 D Dewailly is already in the database.
# 	 Adding D Dewailly to network.
# 	 Adding connection between M Portnoi and D Dewailly.
#
# 	 Adding J L Taillemite in database.
# Adding J L Taillemite:
# 	 J L Taillemite is already in the database.
# 	 Adding J L Taillemite to network.
# 	 Adding connection between M Portnoi and J L Taillemite.
#
# 	 Adding Francis Mulholland in database.
# Adding Francis Mulholland:
# 	 Francis Mulholland is already in the database.
# 	 Adding Francis Mulholland to network.
# 	 Adding connection between M Portnoi and Francis Mulholland.
#
# 	 Adding Clarisse Baumann in database.
# Adding Clarisse Baumann:
# 	 Clarisse Baumann is already in the database.
# 	 Adding Clarisse Baumann to network.
# 	 Adding connection between M Portnoi and Clarisse Baumann.
#
# 	 Adding Hans Joenje in database.
# Adding Hans Joenje:
# 	 Hans Joenje is already in the database.
# 	 Adding Hans Joenje to network.
# 	 Adding connection between M Portnoi and Hans Joenje.

# %%
for i in G.neighbors_iter(gn.name_id['Arseny Alexeev']):
    print(gn.id_info[i].name)
# Out:
# I A Shelykh
# C. David Wright
# Venkata Karthik Nagareddy
# Andrea Ferrari
# Alessandro Curioni
# Monica Felicia Craciun
# Tobias Bachmann
# Anna Ott
# C Dou
# Matthew D. Barnes
# C Scheu
# Wabe Koelmans
# Chunmeng Duo
# Khue T. Lai
# Matthias Wuttig
# S Zhang
# Richard R Hartmann
# Vara Sudananda Prasad Jonnalagadda
# Federico Zipoli
# Evangelos S Eleftheriou
# Abu Sebastian
# Oana Cojocarumiredin
# M E Portnoi

# %%
response = requests.get('https://scholar.google.com' + '/citations/images/avatar_scholar_128.jpg')
img = Image.open(BytesIO(response.content))

# %%
labels = {}

for n in G.nodes():
    labels[n] = gn.id_info[n].name

# %%
f = plt.figure(figsize=(200,400))
ax = f.add_subplot(111)
pos=nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos, ax=ax, node_shape='_', node_color='blue')
nx.draw_networkx_edges(G, pos, edge_color='grey')
nx.draw_networkx_labels(G, pos, ax=ax, labels=labels)
f.savefig("graph.png")
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
nx.write_graphml(G, 'crossref-network')

# %%
w = csv.writer(open("crossref-name_id.csv", "w"))
for key, val in gn.name_id.items():
    w.writerow([key, val])

# %%
for key, val in csv.reader(open("crossref-name_id.csv")):
    gn.name_id[key] = val
